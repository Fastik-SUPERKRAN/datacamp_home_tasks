# %% [markdown]
# # Spacy

# %% [markdown]
# spaCy is a free, open-source library for advanced Natural Language Processing (NLP) in Python.
#
# If you’re working with a lot of text, you’ll eventually want to know more about it. For example, what’s it about? What do the words mean in context? Who is doing what to whom? What companies and products are mentioned? Which texts are similar to each other?
#
# spaCy is designed specifically for production use and helps you build applications that process and “understand” large volumes of text. It can be used to build information extraction or natural language understanding systems, or to pre-process text for deep learning.

# %% [markdown]
# ### Features
#
# | NAME                              | DESCRIPTION                                                                                                        |
# |-----------------------------------|--------------------------------------------------------------------------------------------------------------------|
# | Tokenization                      | Segmenting text into words, punctuations marks etc.                                                                |
# | Part-of-speech (POS) Tagging      | Assigning word types to tokens, like verb or noun.                                                                 |
# | Dependency Parsing                | Assigning syntactic dependency labels, describing the relations between individual tokens, like subject or object. |
# | Lemmatization                     | Assigning the base forms of words. For example, the lemma of “was” is “be”, and the lemma of “rats” is “rat”.      |
# | Sentence Boundary Detection (SBD) | Finding and segmenting individual sentences.                                                                       |
# | Named Entity Recognition (NER)    | Labelling named “real-world” objects, like persons, companies or locations.                                        |
# | Entity Linking (EL)               | Disambiguating textual entities to unique identifiers in a knowledge base.                                         |
# | Similarity                        | Comparing words, text spans and documents and how similar they are to each other.                                  |
# | Text Classification               | Assigning categories or labels to a whole document, or parts of a document.                                        |
# | Rule-based Matching               | Finding sequences of tokens based on their texts and linguistic annotations, similar to regular expressions.       |
# | Training                          | Updating and improving a statistical model’s predictions.                                                          |
# | Serialization                     | Saving objects to files or byte strings.                                                                           |

# %%
import spacy
# Out:
# 2021-08-18 17:10:01.932410: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-18 17:10:01.932483: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Downloading models
#
# https://spacy.io/usage/models

# %%
#!python -m spacy download en_core_web_lg

# %% [markdown]
# ### Creating nlp pipeline
#
# At the center of spaCy is the object containing the processing pipeline. We usually call this variable "nlp". You can use the nlp object like a function to analyze text.It contains all the different components in the pipeline.
# It also includes language-specific rules used for tokenizing the text into words and punctuation. spaCy supports a variety of languages that are available in spacy.lang

# %%
nlp = spacy.load("en_core_web_lg")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# ### The Doc object
#
# When you process a text with the nlp object, spaCy creates a Doc object – short for "document". The Doc lets you access information about the text in a structured way, and no information is lost.
# The Doc behaves like a normal Python sequence by the way and lets you iterate over its tokens, or get a token by its index. But more on that later!

# %%
# Created by processing a string of text with the nlp object
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# Iterate over tokens in a Doc
for token in doc:
    print(token.text)
    
print(type(doc))
doc
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion
# <class 'spacy.tokens.doc.Doc'>
# Apple is looking at buying U.K. startup for $1 billion

# %% [markdown]
# ### The Token object
#
# Token objects represent the tokens in a document – for example, a word or a punctuation character.
# To get a token at a specific position, you can index into the doc.
# Token objects also provide various attributes that let you access more information about the tokens. For example, the .text attribute returns the verbatim token text.
#
# <img src="./img/spacy1.png">

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# Index into the Doc to get a single Token
token = doc[2]

# Get the token text via the .text attribute
print(token.text)
# Out:
# looking

# %% [markdown]
# ### Tokenization
# Segment text into words, punctuations marks, etc.

# %%
tokens = nlp.tokenizer("""
Tokenization segments text into words, punctuations marks, etc. 
It is smarter than regex. 
It won't split the U.K. for example.
""")
list(tokens)
# Out:
# [,
#  Tokenization,
#  segments,
#  text,
#  into,
#  words,
#  ,,
#  punctuations,
#  marks,
#  ,,
#  etc,
#  .,
#  ,
#  It,
#  is,
#  smarter,
#  than,
#  regex,
#  .,
#  ,
#  It,
#  wo,
#  n't,
#  split,
#  the,
#  U.K.,
#  for,
#  example,
#  .,
#  ]

# %% [markdown]
# ### POS tagging
#
#
# For each token in the doc, we can print the text and the .pos_ attribute, the predicted part-of-speech tag.

# %%
doc = nlp("She ate the pizza. Billion is a number")

# Iterate over the tokens
for token in doc:
    # Print the text and the predicted part-of-speech tag
    print(token.text, token.pos_)
# Out:
# She PRON
# ate VERB
# the DET
# pizza NOUN
# . PUNCT
# Billion NUM
# is AUX
# a DET
# number NOUN

# %% [markdown]
# ### Predicting Syntactic Dependencies
# In addition to the part-of-speech tags, we can also predict how the words are related. For example, whether a word is the subject of the sentence or an object.
#
# The .dep_ attribute returns the predicted dependency label.
#
# The .head attribute returns the syntactic head token. You can also think of it as the parent token this word is attached to.
#
# <img src="img/1.png">

# %%
doc = nlp("She ate the pizza")

for token in doc:
    print(token.text, token.pos_, token.dep_, token.head.text)
# Out:
# She PRON nsubj ate
# ate VERB ROOT ate
# the DET det pizza
# pizza NOUN dobj ate

# %% [markdown]
# ### Lemmatization

# %%
doc = nlp("Apple is looking at buying U.K. startup for 1 billion of dollars")

for token in doc:
    print(token.text, token.lemma_)
# Out:
# Apple Apple
# is be
# looking look
# at at
# buying buy
# U.K. U.K.
# startup startup
# for for
# 1 1
# billion billion
# of of
# dollars dollar

# %% [markdown]
# ### Named Entity Recognition

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# Iterate over the predicted entities
for ent in doc.ents:
    # Print the entity text and its label
    print(ent.text, ent.label_)
# Out:
# Apple ORG
# U.K. GPE
# $1 billion MONEY

# %% [markdown]
# #### Hint: Spacy Explain
# To get definitions for the most common tags and labels, you can use the spacy.explain helper function.
#
# For example, "GPE" for geopolitical entity isn't exactly intuitive – but spacy.explain can tell you that it refers to countries, cities and states.
#
# The same works for part-of-speech tags and dependency labels.

# %%
print(spacy.explain("GPE"))
print(spacy.explain("nsubj"))
print(spacy.explain("DET"))
# Out:
# Countries, cities, states
# nominal subject
# determiner

# %% [markdown]
# # Semantic Similarity

# %% [markdown]
# spaCy can compare two objects and predict how similar they are – for example, documents, spans or single tokens.
#
# The Doc, Token and Span objects have a .similarity method that takes another object and returns a floating point number between 0 and 1, indicating how similar they are.
#
# One thing that's very important: In order to use similarity, you need a larger spaCy model that has word vectors included.
#
# By default, the similarity returned by spaCy is the cosine similarity between two vectors – but this can be adjusted if necessary.

# %%
doc1 = nlp("I like fast food")
doc2 = nlp("I like burgers")
doc3 = nlp("Apple is looking at buying U.K. startup for $1 billion")
print(doc1.similarity(doc2))
print(doc1.similarity(doc3))
# Out:
# 0.8469945912019771
# 0.6275414160796284

# %% [markdown]
# https://spacy.io/usage/spacy-101

# %% [markdown]
# # Word Embeddings

# %% [markdown]
# Similarity is determined using word vectors, multi-dimensional representations of meanings of words.

# %% [markdown]
# ## Word representation
#
# Recall onehot  representation
#
# $$boy \qquad \qquad \, girl\quad \qquad \quad apple\qquad \quad orange\qquad \qquad king\qquad \qquad queen\qquad \qquad\\ \begin{bmatrix} 0 \\ \vdots  \\ 0 \\ 1 \\ 0 \\ \quad  \\ \vdots  \\ \quad  \\ \quad  \\ \quad  \\ 0 \end{bmatrix}\begin{matrix} \quad  \\ \leftarrow 1458 \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \end{matrix}\begin{bmatrix} 0 \\ \vdots  \\ \quad  \\ 0 \\ 1 \\ 0 \\ \vdots  \\ \quad  \\ \quad  \\ \quad  \\ 0 \end{bmatrix}\begin{matrix} \quad  \\ \quad  \\ \leftarrow 3945 \\ \quad  \\ \quad  \\ \quad  \\ \quad  \end{matrix}\begin{bmatrix} 0 \\ \vdots  \\ 1 \\ 0 \\ 1 \\ 0 \\ \vdots  \\ \quad  \\ \quad  \\ \quad  \\ 0 \end{bmatrix}\begin{matrix} \leftarrow 472 \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \end{matrix}\begin{bmatrix} 0 \\ \quad  \\ \quad  \\ \quad  \\ \vdots  \\ \quad  \\ \quad  \\ 1 \\ 0 \\ \vdots  \\ 0 \end{bmatrix}\begin{matrix} \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \leftarrow 6117 \\ \quad  \end{matrix}\begin{bmatrix} 0 \\ \quad  \\ \vdots  \\ \quad  \\ 0 \\ 1 \\ 0 \\ \quad  \\ \vdots  \\ \quad  \\ 0 \end{bmatrix}\begin{matrix} \quad  \\ \quad  \\ \quad  \\ \leftarrow 4924 \\ \quad  \\ \quad  \\ \quad  \end{matrix}\begin{bmatrix} 0 \\  \\ \quad  \\ \quad  \\ \vdots  \\ \quad  \\ \quad  \\ \quad  \\ 0 \\ 1 \\ 0 \end{bmatrix}\begin{matrix} \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \quad  \\ \leftarrow 9714\quad  \\ \quad  \end{matrix}\\ \quad$$
#
#
# This representation does not provide any relation for similar words e.g.
# <br>`I like apple juice` and   `I like orange juice`

# %% [markdown]
# The target is to get **vectorized reprezentation** even if vectors are not semantically defined.
#
# The target vectors are expected to be similar by cosine similairity for semantically similar words.
#
# <img src="img/2.png" align = 'left' style="width:350;height:250px;"> <br>
# <div style="clear:left;"></div>
#
# If model is trained using such vectors then having in traing set $\quad$ `I like apple` <u><b> juice </b></u>,  <br>  would make easier to predict $\quad$ <u><b> juice </b></u> $\quad$ for $\quad$  `I like orange` <u><b> $\text{_____}$ </b></u>

# %% [markdown]
# ### Spacy

# %%
doc = nlp("I have a banana")
# Access the vector via the token.vector attribute
print(len(doc[3].vector))
print(doc[3].vector)
# Out:
# 300
# [ 2.0228e-01 -7.6618e-02  3.7032e-01  3.2845e-02 -4.1957e-01  7.2069e-02
#  -3.7476e-01  5.7460e-02 -1.2401e-02  5.2949e-01 -5.2380e-01 -1.9771e-01
#  -3.4147e-01  5.3317e-01 -2.5331e-02  1.7380e-01  1.6772e-01  8.3984e-01
#   5.5107e-02  1.0547e-01  3.7872e-01  2.4275e-01  1.4745e-02  5.5951e-01
#   1.2521e-01 -6.7596e-01  3.5842e-01 -4.0028e-02  9.5949e-02 -5.0690e-01
#  -8.5318e-02  1.7980e-01  3.3867e-01  1.3230e-01  3.1021e-01  2.1878e-01
#   1.6853e-01  1.9874e-01 -5.7385e-01 -1.0649e-01  2.6669e-01  1.2838e-01
#  -1.2803e-01 -1.3284e-01  1.2657e-01  8.6723e-01  9.6721e-02  4.8306e-01
#   2.1271e-01 -5.4990e-02 -8.2425e-02  2.2408e-01  2.3975e-01 -6.2260e-02
#  -8.8650e-02 -3.0298e-01 -1.3591e-01 -2.7765e-01  3.1286e-03  2.0556e-01
#  -1.5772e-01 -5.2308e-01 -6.4701e-01 -3.7014e-01  6.9393e-02  1.1401e-01
#   2.7594e-01 -1.3875e-01 -2.7268e-01  6.6891e-01 -5.6454e-02  2.4017e-01
#  -2.6730e-01  2.9860e-01  1.0083e-01  5.5592e-01  3.2849e-01  7.6858e-02
#   1.5528e-01  2.5636e-01 -1.0772e-01 -1.2359e-01  1.1827e-01 -9.9029e-02
#  -3.4328e-01  1.1502e-01 -3.7808e-01 -3.9012e-02 -3.4593e-01 -1.9404e-01
#  -3.3580e-01 -6.2334e-02  2.8919e-01  2.8032e-01 -5.3741e-01  6.2794e-01
#   5.6955e-02  6.2147e-01 -2.5282e-01  4.1670e-01 -1.0108e-02 -2.5434e-01
#   4.0003e-01  4.2432e-01  2.2672e-01  1.7553e-01  2.3049e-01  2.8323e-01
#   1.3882e-01  3.1218e-03  1.7057e-01  3.6685e-01  2.5247e-03 -6.4009e-01
#  -2.9765e-01  7.8943e-01  3.3168e-01 -1.1966e+00 -4.7156e-02  5.3175e-01]

# %% [markdown]
# ### Word2Vec
# https://uk.wikipedia.org/wiki/Word2vec
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying show me your friends, and I'll tell who you are. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words shocked,appalled and astonished are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the original Word2Vec implementation by Google and extended with additional functionality.

# %% [markdown]
# #### Training word2vec model using gensim

# %%
import gzip
import gensim

# %% [markdown]
# #### Loading data

# %%
input_file = "./data/reviews_data.txt.gz"

with gzip.open(input_file, 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    print("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open(input_file, 'rb') as f:
        for i, line in enumerate (f): 
            if (i%10000==0):
                print("read {0} reviews".format(i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess(line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list(read_input(input_file))
print("Done reading data file")
# Out:
# reading file ./data/reviews_data.txt.gz...this may take a while
# read 0 reviews
# read 10000 reviews
# read 20000 reviews
# read 30000 reviews
# read 40000 reviews
# read 50000 reviews
# read 60000 reviews
# read 70000 reviews
# read 80000 reviews
# read 90000 reviews
# read 100000 reviews
# read 110000 reviews
# read 120000 reviews
# read 130000 reviews
# read 140000 reviews
# read 150000 reviews
# read 160000 reviews
# read 170000 reviews
# read 180000 reviews
# read 190000 reviews
# read 200000 reviews
# read 210000 reviews
# read 220000 reviews
# read 230000 reviews
# read 240000 reviews
# read 250000 reviews
# Done reading data file

# %% [markdown]
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the documents). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary.
#
# After building the vocabulary, we just need to call train(...) to start training the Word2Vec model. Training on the OpinRank dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# <img src="img/7.png">

# %%
model = gensim.models.Word2Vec(documents, vector_size=150, window=10, min_count=2, workers=24)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (303494579, 415193580)

# %%
import pickle

# with open("./w2v.model", "wb") as f:
#     pickle.dump(model, f)
    
with open("./w2v.model", "rb") as f:
    model = pickle.load(f)

# %%
word_v= model.wv.get_vector('hello')
print(len(word_v))
print(word_v)
# Out:
# 150
# [-1.3899217  -0.3737228  -2.666311    3.54252     3.2357097   0.20491503
#  -2.1295466   0.54146177 -0.6249488   2.6508749   1.5873171  -5.1272163
#  -3.084422    3.939809   -2.0652852   0.2448739  -0.43315598  0.3170544
#  -2.1743352  -0.57942677 -3.5716836   0.786738   -0.0889107  -3.9856489
#   2.4038577   6.2939167  -1.6515285  -1.6507418  -0.8590235   4.383898
#   2.71958    -6.02498    -2.510434    0.84199876 -0.8735189  -2.5513418
#   2.097896    0.15211919  0.65232474 -2.0750084  -0.25561252  0.5879701
#   4.7977505  -0.40362814 -1.4729497   4.4881735   3.239752    1.4243891
#  -4.498614    5.750339   -1.8617357  -0.34265506 -2.1606433   5.9471455
#   1.7514248  -0.6553776  -4.166816   -1.3523401   2.388277    1.7823781
#  -4.9179635  -1.002605    1.7314526   0.05238996 -1.3864789  -4.0298486
#  -2.1944242  -2.126804    1.9887234   0.33664438 -3.884635    0.5266325
#   1.7292053  -0.43828267 -4.6069155   1.3125004  -1.2170959  -3.6522167
#  -0.3835142  -4.174236    1.0721489   0.41395473 -1.2947817   3.2164288
#   2.3248062  -1.181893   -1.2563884   3.9561133   1.1716213  -3.6321025
#   1.6425216  -1.2963842  -3.6846342   0.52681094  0.3774697   3.2039242
#   1.0571756   0.13866353  2.0685456  -1.8494731  -0.09421885  2.1209035
#  -2.0908813   0.03564257  2.7787275   0.84269893  2.7161937  -0.57248014
#  -2.401758   -2.2186987  -2.7042193   2.1737788  -1.4834505  -1.1735379
#   1.8907497  -0.41786826 -1.0460123  -1.8682743   0.77331704  0.47429055
#  -0.38386586  4.678882   -5.0225863  -2.2982233  -1.4288104  -4.3230314
#   3.26564     2.4038477   0.01018189 -1.8920052   0.6933659   1.1951381
#  -0.16951315 -2.5364497   0.7042575  -1.3957359   2.3054404   0.3186625
#  -0.1493916   0.7062319  -2.6402528   4.332916   -3.0479782   2.2044754
#   4.3160925   0.31483918  1.1724918   2.461174   -4.0212154  -2.7949066 ]

# %% [markdown]
# #### Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word dirty. All we need to do here is to call the most_similar function and provide the word dirty as the positive example. This returns the top 10 similar words.

# %%
w1 = "dirty"
model.wv.most_similar(positive=w1)
# Out:
# [('filthy', 0.8643262386322021),
#  ('stained', 0.783256471157074),
#  ('unclean', 0.7817822098731995),
#  ('smelly', 0.7720529437065125),
#  ('dusty', 0.7595260143280029),
#  ('grubby', 0.7468538880348206),
#  ('mouldy', 0.7240976095199585),
#  ('soiled', 0.723734974861145),
#  ('gross', 0.7211849689483643),
#  ('dingy', 0.7200460433959961)]

# %%
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9287809729576111),
#  ('friendly', 0.8312320709228516),
#  ('professional', 0.7926158308982849),
#  ('cordial', 0.790034294128418),
#  ('attentive', 0.7775870561599731),
#  ('curteous', 0.7551116347312927)]

# %%
w1 = ["vehicle"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('car', 0.7947025895118713),
#  ('vehicles', 0.6487293243408203),
#  ('minivan', 0.6484553217887878),
#  ('suv', 0.6222910284996033),
#  ('cars', 0.5939807295799255),
#  ('baggages', 0.5902112126350403)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that relate to bed only:

# %% [markdown]
# ### Analogy reasoning
#
# $boy - girl =  \begin{bmatrix} \text{~ 0} \\ \text{~ 2} \\ \text{~ 0} \\ \text{~ 0} \\  \text{~ 0} \\ \vdots \\ \text{~ 0}  \\ \end{bmatrix} \qquad king - queen =  \begin{bmatrix} \text{~ 0} \\ \text{~ 2} \\ \text{~ 0} \\ \text{~ 0} \\  \text{~ 0} \\ \vdots \\ \text{~ 0}  \\ \end{bmatrix}$
#
# We may say:  `boy` - `girl` = `king` - `queen`
#
# Furher, answer the questions like `boy` is to `girl` as `king` is to `WHO?`

# %%
result = model.wv.most_similar(positive=['king', 'woman'], negative=['man'], topn=1)

# king - man + woman = ?

print(result)
# Out:
# [('queen', 0.7679240703582764)]

# %%
result = model.wv.most_similar(positive=["doctor", "woman"], negative=['man'], topn=1)

# doctor - man + woman = ?

print(result)
# Out:
# [('nurse', 0.5307596325874329)]

# %%
result = model.wv.most_similar(positive=["huge", "small"], negative=['big'], topn=1)

# huge - big + small = ?

print(result)
# Out:
# [('tiny', 0.7188771367073059)]

# %% [markdown]
# #### Similarity between two words in the vocabulary

# %%
print('similarity between two identical words')
print(model.wv.similarity(w1="dirty",w2="dirty"))

print('\nsimilarity between two different words')
print(model.wv.similarity(w1="dirty",w2="smelly"))
print(model.wv.similarity(w1="bye",w2="goodbye"))
print(model.wv.similarity(w1="car",w2="vehicle"))

print('\nsimilarity between two opposit words')
print(model.wv.similarity(w1="dirty",w2="clean"))
print(model.wv.similarity(w1="wet",w2="dry"))

print('\nsimilarity between two unrelated words')
print(model.wv.similarity(w1="green",w2="hotel"))
print(model.wv.similarity(w1="hello",w2="the"))
# Out:
# similarity between two identical words
# 1.0
#
# similarity between two different words
# 0.77205294
# 0.54594237
# 0.79470253
#
# similarity between two opposit words
# 0.27225775
# 0.4558458
#
# similarity between two unrelated words
# 0.0042668898
# -0.023576831

# %% [markdown]
# Under the hood, it computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that dirty is highly similar to smelly but dirty is dissimilar to clean. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring here.

# %% [markdown]
# #### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","sheet","shower"])
# Out:
# 'shower'

# %% [markdown]
# ### USE - Universal Sentence Encoder

# %% [markdown]
# The Universal Sentence Encoder encodes text into high dimensional vectors that can be used for text classification, semantic similarity, clustering and other natural language tasks.
#
# The model is trained and optimized for greater-than-word length text, such as sentences, phrases or short paragraphs. It is trained on a variety of data sources and a variety of tasks with the aim of dynamically accommodating a wide variety of natural language understanding tasks. The input is variable length English text and the output is a 512 dimensional vector.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

# %%
# Import the Universal Sentence Encoder's TF Hub module
# It may take a while

# module_url = "https://tfhub.dev/google/universal-sentence-encoder/3" 
# embed = hub.Module(module_url)

# or download the model and use it locally

embed = tf.saved_model.load("./USE/")
# Out:
# 2021-08-18 17:30:40.329336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-18 17:30:40.330294: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.330443: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.330571: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.637184: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.637525: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.637800: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2021-08-18 17:30:40.637835: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-18 17:30:40.638959: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-18 17:30:57.330191: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# Compute a representation for each message, showing various lengths supported.
word = "Elephant"
sentence = "I am a sentence for which I would like to get its embedding."
paragraph = (
    "Universal Sentence Encoder embeddings also support short paragraphs. "
    "There is no hard limit on how long the paragraph is. Roughly, the longer "
    "the more 'diluted' the embedding will be.")
messages = [word, sentence, paragraph]


message_embeddings = embed(messages)

for i, message_embedding in enumerate(np.array(message_embeddings).tolist()):
    print("Message: {}".format(messages[i]))
    print("Embedding size: {}".format(len(message_embedding)))
    message_embedding_snippet = ", ".join(
        (str(x) for x in message_embedding[:3]))
    print("Embedding: [{}, ...]\n".format(message_embedding_snippet))
# Out:
# Message: Elephant
# Embedding size: 512
# Embedding: [0.008344483561813831, 0.00048085584421642125, 0.06595248728990555, ...]
#
# Message: I am a sentence for which I would like to get its embedding.
# Embedding size: 512
# Embedding: [0.050808604806661606, -0.0165242962539196, 0.01573782227933407, ...]
#
# Message: Universal Sentence Encoder embeddings also support short paragraphs. There is no hard limit on how long the paragraph is. Roughly, the longer the more 'diluted' the embedding will be.
# Embedding size: 512
# Embedding: [-0.02833269163966179, -0.0558621808886528, -0.012941432185471058, ...]

# %%
str1 = "I like my bike"
str2 = "My motorcycle looks good"
str3 = "Two more cells and we are done"

messages = [str1, str2, str3]
emb1, emb2, emb3 = embed(messages)

print(f"The similarity between '{str1}' and '{str2}' = {np.inner(emb1, emb2)}")
print(f"The similarity between '{str1}' and '{str3}' = {np.inner(emb1, emb3)}")
# Out:
# The similarity between 'I like my bike' and 'My motorcycle looks good' = 0.7165157198905945
# The similarity between 'I like my bike' and 'Two more cells and we are done' = 0.0004695691168308258

# %%
def plot_similarity(labels, features, rotation):
    corr = np.inner(features, features)
    sns.set(font_scale=1.2)
    g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
    g.set_xticklabels(labels, rotation=rotation)
    g.set_title("Semantic Textual Similarity")


def run_and_plot(messages, encoding_tensor):
    message_embeddings = encoding_tensor(messages)
    plot_similarity(messages, message_embeddings, 90)

# %%
messages = [
    # Smartphones
    "I like my phone",
    "My phone is not good.",
    "Your cellphone looks great.",

    # Weather
    "Will it snow tomorrow?",
    "Recently a lot of hurricanes have hit the US",
    "Global warming is real",

    # Food and health
    "An apple a day, keeps the doctors away",
    "Eating strawberries is healthy",
    "Is paleo better than keto?",

    # Asking about age
    "How old are you?",
    "what is your age?",
]

run_and_plot(messages, embed)

# %% [markdown]
# 1. Using a Spacy, create a keywords extractor that should do the following things:
#  - Take some text (article like) as an input.
#  - Remove all stop words from the text.
#  - Extract all the Nouns from text and sort them by count and return in descending order with amount of occurrences.
#  - Extract all the Verbs from text and sort them by count and return in descending order with amount of occurrences.
#  - Extract all the Numbers from text and sort them by count and return in descending order with amount of occurrences.
#  - Extract all the Named Entities from the text, group them into 4 groups (Location, Person, Organization, Misc.) and return groups in descending order with amount of occurrences.
#
#
# 2. Using multilingual USE, align strings in English and Russian texts:
#  - Download multilingual USE model - https://tfhub.dev/google/universal-sentence-encoder-multilingual/3
#  - Read "./data/corpora/en.txt" and "./data/corpora/ru.txt" files
#  - Align English strings with their Russian analogues using mUSE
#
#
# 3. Using the USE, create a Duplicate Phrase Finder that will do the following:
#  - Take some large text as an input.
#  - Separates text to SENTENCES (phrases).
#  - Finds semantically similar strings (cosine similarity >=0.80)

# %% [markdown]
# # Home task

# %%
# Read "./data/corpora/en.txt" and "./data/corpora/ru.txt" files

en = []
ru = []
with open("./data/corpora/en.txt") as f:
    for line in f.readlines()[:50]:
        en.append(line.strip())
        
with open("./data/corpora/ru.txt") as f:
    for line in f.readlines()[:50]:
        ru.append(line.strip())

# %% [markdown]
# # 1. Using a Spacy, create a keywords extractor

# %%
from nltk.corpus import gutenberg
import spacy
from collections import Counter

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 2.2 MB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from en-core-web-sm==3.1.0) (3.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: setuptools in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (56.0.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.21.0)
# Requirement already satisfied: jinja2 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.7.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/lib/python3.9/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/fastik/Projects/datacamp_home_tasks/.virtualenv/datacamp_home_tasks/bin/python3 -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
class KeywordsExtractor:
    def __init__(self, text: str, nlp: spacy.lang) -> None:
        """ой та влом робити досктрінги і так все понятно

        Args:
            text (str): [description]
            nlp (spacy.lang): output of spacy.load
        """
        self.text = text
        self._nlp = nlp

    @staticmethod
    def _remove_stopwords(text: list[str], nlp) -> list[spacy.tokens.token.Token]:
        """Removes stopwords and tokenizes text (〜￣▽￣)〜

        Args:
            text (str): [description]
            nlp (spacy.lang): output of spacy.load

        Returns:
            list of spacy.tokens.token.Token: [description]
        """
        return [token for token in nlp(text) if not token.is_stop]

    @staticmethod
    def _extract_nouns(tokenized_text: list[spacy.tokens.token.Token]) -> list[str]:
        """Extract all the Nouns from text and sort them by count and return in descending order with amount of occurrences.

        Args:
            text (list of str): [description]

        Returns:
            list of str: [description]
        """
        return Counter(token.text for token in tokenized_text if token.pos_ == 'NOUN').most_common()

    @staticmethod
    def _extract_verbs(tokenized_text: list[spacy.tokens.token.Token]) -> list[str]:
        """Extract all the Verbs from text and sort them by count and return in descending order with amount of occurrences.

        Args:
            text (list of str): [description]

        Returns:
            list of str: [description]
        """
        return Counter(token.text for token in tokenized_text if token.pos_ == 'VERB').most_common()

    @staticmethod
    def _extract_numbers(tokenized_text: list[spacy.tokens.token.Token]) -> list[str]:
        """Extract all the Numbers from text and sort them by count and return in descending order with amount of occurrences.

        Args:
            text (list of str): [description]

        Returns:
            list of str: [description]
        """
        return Counter(token.text for token in tokenized_text if token.pos_ == 'NUM').most_common()

    @staticmethod
    def _extract_named_entities(tokenized_text: list[spacy.tokens.token.Token]) -> list[str]:
        """Extract all the Named Entities from the text, group them into 4 groups (Location, Person, Organization, Misc.) and return groups in descending order with amount of occurrences.
        невпевнений що я правильно поняв що тут треба робити але якось так (。_。)

        Args:
            text (list of str): [description]

        Returns:
            list of str: [description]
        """
        return Counter(token.ent_type_ if token.ent_type_ in ['LOC', 'PERSON', 'ORG'] else 'Misc.' for token in tokenized_text).most_common()

    def __str__(self) -> str:
        return '\n'.join(
            [
                f'KeywordsExtractor class used on text: {self.text.split(" ")[:10]}\n',
                f'{self.extracted_nouns[:10] = }',
                f'{self.extracted_verbs[:10] = }',
                f'{self.extracted_numbers[:10] = }',
                f'{self.extracted_named_entities[:10] = }',
            ]
        )

    def execute(self) -> None:
        """Executes KeywordsExctractor 〜(￣▽￣〜)"""
        self._tokenized_text = self._remove_stopwords(self.text, self._nlp)

        self.extracted_nouns = self._extract_nouns(self._tokenized_text)
        self.extracted_verbs = self._extract_verbs(self._tokenized_text)
        self.extracted_numbers = self._extract_numbers(self._tokenized_text)
        self.extracted_named_entities = self._extract_named_entities(self._tokenized_text)

        print('Done ✍(◔◡◔)')

        print(self)

# %%
text = gutenberg.raw('shakespeare-hamlet.txt')
nlp = spacy.load('en_core_web_sm')

extractor = KeywordsExtractor(text, nlp)
extractor.execute()
# Out:
# Done ✍(◔◡◔)
# KeywordsExtractor class used on text: ['[The', 'Tragedie', 'of', 'Hamlet', 'by', 'William', 'Shakespeare', '1599]\n\n\nActus', 'Primus.', 'Scoena']
#
# self.extracted_nouns[:10] = [('Ham', 64), ('selfe', 41), ('man', 41), ('loue', 38), ('time', 37), ('death', 36), ('heere', 31), ('life', 30), ('night', 28), ('againe', 26)]
# self.extracted_verbs[:10] = [('haue', 118), ('Enter', 70), ('know', 68), ('come', 67), ('let', 61), ('Let', 42), ('tell', 39), ('thinke', 35), ('Come', 33), ('giue', 32)]
# self.extracted_numbers[:10] = [('tis', 12), ('thousand', 8), ('thee', 4), ('Tis', 4), ('1.Play', 3), ('1599', 1), ("can'st", 1), ("deliuer'd", 1), ("honour'd", 1), ("crack'd", 1)]
# self.extracted_named_entities[:10] = [('Misc.', 23584), ('PERSON', 888), ('ORG', 464), ('LOC', 31)]

# %% [markdown]
# # 2. Using multilingual USE, align strings in English and Russian texts

# %%
# Read "./data/corpora/en.txt" and "./data/corpora/ru.txt" files

en = []
ru = []
with open("./data/corpora/en.txt") as f:
    for line in f.readlines()[:50]:
        en.append(line.strip())
        
with open("./data/corpora/ru.txt") as f:
    for line in f.readlines()[:50]:
        ru.append(line.strip())

# %%
import numpy as np
import seaborn as sns

import tensorflow_hub as hub
import tensorflow_text


def plot_similarity(labels, features):
    print(len(features[0]))
    corr = np.inner(features[0], features[1])
    sns.set(font_scale=1.2)
    g = sns.heatmap(
        corr,
        xticklabels=labels[1],
        yticklabels=labels[0],
        vmin=0,
        vmax=1,
        cmap="YlOrRd"
    )
    g.set_title("Semantic Textual Similarity")

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-multilingual/3")

en_result = embed(en)
ru_result = embed(ru)

# %%
plot_similarity(labels=(en, ru), features=(en_result, ru_result))
# Out:
# 6

# %% [markdown]
# # 3. Using the USE, create a Duplicate Phrase Finder that will do the following

# %%
from itertools import product

import numpy as np

from nltk.corpus import gutenberg
import spacy

import tensorflow_hub as hub
import tensorflow_text

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-multilingual/3")

nlp = spacy.load('en_core_web_sm')

text = gutenberg.raw('shakespeare-hamlet.txt')

sentences = [token.text.strip() for token in nlp(text).sents if token.text.strip()]

sent_result = embed(sentences)

similarity_matrix = np.inner(sent_result, sent_result)

# %%
for ii, jj in product(range(len(similarity_matrix)), repeat=2):
    if similarity_matrix[ii][jj] >= 0.8 and sentences[ii] != sentences[jj]:
        print(f'Found similar sentences (cosine similarity - {similarity_matrix[ii][jj]})')
        print(sentences[ii])
        print(sentences[jj])
# Out:
# Found similar sentences (cosine similarity - 0.8528488278388977)
# Barnardo.
# Barnardo?
# Found similar sentences (cosine similarity - 0.8366587162017822)
# Who's there?
# Who?
# Found similar sentences (cosine similarity - 0.8366587162017822)
# Who's there?
# Who?
# Found similar sentences (cosine similarity - 0.8740794658660889)
# Fran.
# He
#
#    Fran.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Fran.
# Exit Fran.
# Found similar sentences (cosine similarity - 0.8528488278388977)
# Barnardo?
# Barnardo.
# Found similar sentences (cosine similarity - 0.8740794658660889)
# He
#
#    Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8740794658660889)
# He
#
#    Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8740794658660889)
# He
#
#    Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8740794658660889)
# Fran.
# He
#
#    Fran.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Fran.
# Exit Fran.
# Found similar sentences (cosine similarity - 0.8513206243515015)
# Enter Horatio and Marcellus.
# Enter Horatio, Barnardo, and Marcellus.
# Found similar sentences (cosine similarity - 0.8740794658660889)
# Fran.
# He
#
#    Fran.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Fran.
# Exit Fran.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Exit Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Exit Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8821110725402832)
# Exit Fran.
# Fran.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.9075630307197571)
# Say, what is Horatio there?
# What hoa, Horatio?
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8647769689559937)
# Marcellus
#
#    Mar.
# Stop it Marcellus
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.839110255241394)
# Horatio
#
#    Barn.
# Horatio
#
#    Hor.
# Found similar sentences (cosine similarity - 0.9188829660415649)
# Lookes it not like the King?
# Is it not like the King?
# Found similar sentences (cosine similarity - 0.9161046743392944)
# Horatio
#
#    Hora.
# Horatio
#
#    Hor.
# Found similar sentences (cosine similarity - 0.839110255241394)
# Horatio
#
#    Hor.
# Horatio
#
#    Barn.
# Found similar sentences (cosine similarity - 0.9161046743392944)
# Horatio
#
#    Hor.
# Horatio
#
#    Hora.
# Found similar sentences (cosine similarity - 0.807691216468811)
# Horatio
#
#    Hor.
# Enter Horatio.
# Found similar sentences (cosine similarity - 0.9526839256286621)
# Exit the Ghost.
# Exit Ghost.
# Found similar sentences (cosine similarity - 0.8688865900039673)
# Exit the Ghost.
# Ghost.
# Found similar sentences (cosine similarity - 0.8688865900039673)
# Exit the Ghost.
# Ghost.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8090013265609741)
# How now Horatio?
# What hoa, Horatio?
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.9188829660415649)
# Is it not like the King?
# Lookes it not like the King?
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8228687644004822)
# Enter Ghost againe.
# Enter Ghost.
# Found similar sentences (cosine similarity - 0.8228687644004822)
# Enter Ghost againe.
# Enter Ghost.
# Found similar sentences (cosine similarity - 0.8647769689559937)
# Stop it Marcellus
#
#    Mar.
# Marcellus
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8647769689559937)
# Stop it Marcellus
#
#    Mar.
# Marcellus
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.9526839256286621)
# Exit Ghost.
# Exit the Ghost.
# Found similar sentences (cosine similarity - 0.8816332817077637)
# Exit Ghost.
# Ghost.
# Found similar sentences (cosine similarity - 0.8816332817077637)
# Exit Ghost.
# Ghost.
# Found similar sentences (cosine similarity - 0.8345048427581787)
# Vnto yong Hamlet.
# Exit Hamlet.
# Found similar sentences (cosine similarity - 0.8260706663131714)
# King.
# Good
#
#    King.
# Found similar sentences (cosine similarity - 0.8564196228981018)
# King.
# Exit
#
#   King.
# Found similar sentences (cosine similarity - 0.9035231471061707)
# Enter Voltemand and Cornelius.
# Exit Voltemand and Cornelius.
# Found similar sentences (cosine similarity - 0.9035231471061707)
# Exit Voltemand and Cornelius.
# Enter Voltemand and Cornelius.
# Found similar sentences (cosine similarity - 0.9307835102081299)
# What is't Laertes?
# How is't Laertes?
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8114373683929443)
# Manet Hamlet.
# Exit Hamlet.
# Found similar sentences (cosine similarity - 0.806019127368927)
# Manet Hamlet.
# Hamlet.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8201333284378052)
# (O Heauen!
# Oh Heauen!
# Found similar sentences (cosine similarity - 0.8513206243515015)
# Enter Horatio, Barnardo, and Marcellus.
# Enter Horatio and Marcellus.
# Found similar sentences (cosine similarity - 0.8513206243515015)
# Enter Horatio, Barnardo, and Marcellus.
# Enter Horatio and Marcellus.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8647769689559937)
# Marcellus
#
#    Mar.
# Stop it Marcellus
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8086974620819092)
# My good Lord
#
#    Ham.
# A truant disposition, good my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8585887551307678)
# My good Lord
#
#    Ham.
# We doe my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8013253808021545)
# My good Lord
#
#    Ham.
# Looke my Lord, it comes
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8211656808853149)
# My good Lord
#
#    Ham.
# Doe not my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.
hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# no
#
#    Hor.
# Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# no
#
#    Hor.
# Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# no
#
#    Hor.
# Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# no
#
#    Hor.
# Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# no
#
#    Hor.
# Hor.
# Found similar sentences (cosine similarity - 0.8021056652069092)
# I warrant you it will
#
#    Ham.
# Fare you well my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8562546372413635)
# I warrant you it will
#
#    Ham.
# I beseech you
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8196548819541931)
# Exeunt
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8196548819541931)
# Exeunt
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8196548819541931)
# Exeunt
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8784445524215698)
# Exeunt
#
#    Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8570960164070129)
# Enter Polonius.
# Exit Polonius.
# Found similar sentences (cosine similarity - 0.911876380443573)
# Polon.
# Exit Polon.
# Found similar sentences (cosine similarity - 0.817816972732544)
# Ophe.
# Farewell
#
#    Ophe.
# Found similar sentences (cosine similarity - 0.9448351860046387)
# Ophe.
# Ophe. '
# Found similar sentences (cosine similarity - 0.817816972732544)
# Ophe.
# Farewell
#
#    Ophe.
# Found similar sentences (cosine similarity - 0.9448351860046387)
# Ophe.
# Ophe. '
# Found similar sentences (cosine similarity - 0.817816972732544)
# Ophe.
# Farewell
#
#    Ophe.
# Found similar sentences (cosine similarity - 0.9448351860046387)
# Ophe.
# Ophe. '
# Found similar sentences (cosine similarity - 0.8628973960876465)
# I do not know, my Lord, what I should thinke
#
#    Polon.
# I my Lord, I would know that
#
#    Polon.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8491554260253906)
# What hower now?
# Whats the matter now?
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# twelue
#
#    Mar.
# Mar.
# Found similar sentences (cosine similarity - 0.8117591142654419)
# What does this meane my Lord?
# What is't my Lord?
# Found similar sentences (cosine similarity - 0.8228435516357422)
# What does this meane my Lord?
# What is my Lord?
# Found similar sentences (cosine similarity - 0.89870685338974)
# What does this meane my Lord?
# What meanes this, my Lord?
# Found similar sentences (cosine similarity - 0.8356013894081116)
# What does this meane my Lord?
# What's that my Lord?
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8228687644004822)
# Enter Ghost.
# Enter Ghost againe.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8013253808021545)
# Looke my Lord, it comes
#
#    Ham.
# My good Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8194451332092285)
# Looke my Lord, it comes
#
#    Ham.
# My Lord, I thinke I saw him yesternight
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8085717558860779)
# Looke my Lord, it comes
#
#    Ham.
# My Lord, from head to foote
#
#    Ham.
# Found similar sentences (cosine similarity - 0.807005763053894)
# Looke my Lord, it comes
#
#    Ham.
# Good my Lord tell it
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8538013100624084)
# Looke my Lord, it comes
#
#    Ham.
# I haue my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.806861162185669)
# Looke my Lord, it comes
#
#    Ham.
# My Lord, I haue Newes to tell you
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8271954655647278)
# Looke my Lord, it comes
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8271954655647278)
# Looke my Lord, it comes
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8325709104537964)
# Looke my Lord, it comes
#
#    Ham.
# There my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8019636869430542)
# Looke my Lord, it comes
#
#    Ham.
# My Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8271954655647278)
# Looke my Lord, it comes
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8271954655647278)
# Looke my Lord, it comes
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.802032470703125)
# Looke my Lord, it comes
#
#    Ham.
# Verie well my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.854851484298706)
# Looke my Lord, it comes
#
#    Ham.
# I, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8422648906707764)
# Looke my Lord, it comes
#
#    Ham.
# E'ene so, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.820432722568512)
# Looke my Lord, it comes
#
#    Ham.
# I, good my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8502596616744995)
# What may this meane?
# What should this meane?
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8026404976844788)
# No, by no meanes
#
#    Ham.
# No indeed, they are not
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8136726021766663)
# No, by no meanes
#
#    Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8211656808853149)
# Doe not my Lord
#
#    Ham.
# My good Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.821725606918335)
# Doe not my Lord
#
#    Ham.
# We doe my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8505153656005859)
# Doe not my Lord
#
#    Ham.
# You shall not goe my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8511248826980591)
# Doe not my Lord
#
#    Ham.
# Nor I, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8516174554824829)
# Doe not my Lord
#
#    Ham.
# There's no offence my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8246023654937744)
# Doe not my Lord
#
#    Ham.
# My Lord, we will not
#
#    Ham.
# Found similar sentences (cosine similarity - 0.9026118516921997)
# Doe not my Lord
#
#    Ham.
# Not I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8457006216049194)
# Doe not my Lord
#
#    Ham.
# I haue my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8747791647911072)
# Doe not my Lord
#
#    Ham.
# Neither my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8398967385292053)
# Doe not my Lord
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8398967385292053)
# Doe not my Lord
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8068877458572388)
# Doe not my Lord
#
#    Ham.
# There my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8287000060081482)
# Doe not my Lord
#
#    Ham.
# My Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8644344210624695)
# Doe not my Lord
#
#    Ham.
# No my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8398967385292053)
# Doe not my Lord
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8127110004425049)
# Doe not my Lord
#
#    Ham.
# I thinke nothing, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8398967385292053)
# Doe not my Lord
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8197076320648193)
# Doe not my Lord
#
#    Ham.
# Verie well my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8079084753990173)
# Doe not my Lord
#
#    Ham.
# No my Lord, rather with choller
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8454878330230713)
# Doe not my Lord
#
#    Ham.
# My Lord, I cannot
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8223754167556763)
# Doe not my Lord
#
#    Ham.
# I vnderstand you not my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8284432291984558)
# Doe not my Lord
#
#    Ham.
# I, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8496168851852417)
# Doe not my Lord
#
#    Ham.
# Not a iot more, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8779280185699463)
# Doe not my Lord
#
#    Ham.
# No my good Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8505153656005859)
# You shall not goe my Lord
#
#    Ham.
# Doe not my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8255255222320557)
# You shall not goe my Lord
#
#    Ham.
# There's no offence my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8019288778305054)
# You shall not goe my Lord
#
#    Ham.
# My Lord, we will not
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8030112981796265)
# You shall not goe my Lord
#
#    Ham.
# Not I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8011032342910767)
# You shall not goe my Lord
#
#    Ham.
# Neither my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8362971544265747)
# You shall not goe my Lord
#
#    Ham.
# I vnderstand you not my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.875821590423584)
# Ghost & Hamlet.
# Enter Ghost and Hamlet.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.875821590423584)
# Enter Ghost and Hamlet.
# Ghost & Hamlet.
# Found similar sentences (cosine similarity - 0.8072981834411621)
# Enter Ghost and Hamlet.
# Enter Hamlet and Guildensterne.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8084425926208496)
# To what I shall vnfold
#
#    Ham.
# I haue my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8409259915351868)
# To what I shall vnfold
#
#    Ham.
# Come one for me
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8010540008544922)
# What?
# What then?
# Found similar sentences (cosine similarity - 0.8201333284378052)
# Oh Heauen!
# (O Heauen!
# Found similar sentences (cosine similarity - 0.9293050765991211)
# Oh Heauen!
# Oh Heauens!
# Found similar sentences (cosine similarity - 0.8688865900039673)
# Ghost.
# Exit the Ghost.
# Found similar sentences (cosine similarity - 0.8816332817077637)
# Ghost.
# Exit Ghost.
# Found similar sentences (cosine similarity - 0.8688865900039673)
# Ghost.
# Exit the Ghost.
# Found similar sentences (cosine similarity - 0.8816332817077637)
# Ghost.
# Exit Ghost.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8009099960327148)
# My Lord, my Lord.
# My Lord, I did;
# Found similar sentences (cosine similarity - 0.9045494794845581)
# My Lord, my Lord.
# Well, my Lord.
# Found similar sentences (cosine similarity - 0.8550727367401123)
# My Lord, my Lord.
# Well my Lord.
# Found similar sentences (cosine similarity - 0.8040101528167725)
# My Lord, my Lord.
# What, my Lord?
# Found similar sentences (cosine similarity - 0.8513206243515015)
# Enter Horatio and Marcellus.
# Enter Horatio, Barnardo, and Marcellus.
# Found similar sentences (cosine similarity - 0.8282808661460876)
# Mar.
# twelue
#
#    Mar.
# Found similar sentences (cosine similarity - 0.8130022287368774)
# Lord Hamlet
#
#    Hor.
# Hamlet, Lord Hamlet
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.
good my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8051176071166992)
# I meane my Lord, the opposition of your person
# in tryall
#
#    Ham.
# I meane the matter you meane, my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8187874555587769)
# Nay, good my Lord
#
#    Ham.
# My good Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8326828479766846)
# Nay, good my Lord
#
#    Ham.
# Verie well my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.9097940325737)
# Nay, good my Lord
#
#    Ham.
# I, good my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8253949880599976)
# Nay, good my Lord
#
#    Ham.
# No my good Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.9377873539924622)
# Kin.
# Kin. '
# Found similar sentences (cosine similarity - 0.8571460247039795)
# Neuer Hamlet.
# Exit Hamlet.
# Found similar sentences (cosine similarity - 0.8552505373954773)
# Neuer Hamlet.
# Hamlet.
# Found similar sentences (cosine similarity - 0.8063044548034668)
# Neuer Hamlet.
# Hamlet, Hamlet
#
#    Gen.
# Found similar sentences (cosine similarity - 0.8409259915351868)
# Come one for me
#
#    Ham.
# To what I shall vnfold
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8050317764282227)
# You mocke me Sir
#
#    Ham.
# I beseech you
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8700871467590332)
# Come on sir.
# Come sirs.
# Found similar sentences (cosine similarity - 0.8042745590209961)
# Come on sir.
# Come on.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8136726021766663)
# No
#
#    Ham.
# No, by no meanes
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8087663650512695)
# No
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8087663650512695)
# No
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8087663650512695)
# No
#
#    Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8298917412757874)
# No
#
#    Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8327114582061768)
# No
#
#    Ham.
# For none neither
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# No
#
#    Ham.
# Ham.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Iudgement
#
#    Osr.
# Osr.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8604573607444763)
# Good Madam
#
#    King.
# Good
#
#    King.
# Found similar sentences (cosine similarity - 0.966915488243103)
# Say you so?
# Say you?
# Found similar sentences (cosine similarity - 0.8042745590209961)
# Come on.
# Come on sir.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8260706663131714)
# King.
# Good
#
#    King.
# Found similar sentences (cosine similarity - 0.8564196228981018)
# King.
# Exit
#
#   King.
# Found similar sentences (cosine similarity - 0.919478714466095)
# How is't my Lord?
# What is't my Lord?
# Found similar sentences (cosine similarity - 0.8611894845962524)
# How is't my Lord?
# What is my Lord?
# Found similar sentences (cosine similarity - 0.8135788440704346)
# How is't my Lord?
# How fares my Lord?
# Found similar sentences (cosine similarity - 0.8272137641906738)
# How is't my Lord?
# What's that my Lord?
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.9307835102081299)
# How is't Laertes?
# What is't Laertes?
# Found similar sentences (cosine similarity - 0.8260706663131714)
# King.
# Good
#
#    King.
# Found similar sentences (cosine similarity - 0.8564196228981018)
# King.
# Exit
#
#   King.
# Found similar sentences (cosine similarity - 0.8071662187576294)
# I am poyson'd
#
#    Ham.
# I haue my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8110689520835876)
# I am poyson'd
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8110689520835876)
# I am poyson'd
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8110689520835876)
# I am poyson'd
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8110689520835876)
# I am poyson'd
#
#    Ham.
# I my Lord
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8361355066299438)
# All.
# Away
#
#    All.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8578506708145142)
# Ham.
# Sweare
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8781094551086426)
# Ham.
# Exit
#
#   Ham.
# Found similar sentences (cosine similarity - 0.8440505266189575)
# Ham.
# No
#
#    Ham.
# Found similar sentences (cosine similarity - 0.8047067523002625)
# Enter Osricke.
# Enter young Osricke.
# Found similar sentences (cosine similarity - 0.8289222717285156)
# Osr.
# Iudgement
#
#    Osr.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8079786896705627)
# Hor.
# no
#
#    Hor.
# Found similar sentences (cosine similarity - 0.8478696346282959)
# Hor.
# Puh
#
#    Hor.
